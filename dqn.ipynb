# %%
# !pip install import-ipynb

# %%
import import_ipynb
import objDet
import dpt_map

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from PIL import Image
#from transformers import DPTFeatureExtractor, DPTForDepthEstimation
#from ultralytics import YOLO
import gym
from gym import spaces
from collections import namedtuple, deque
import random
import cv2
import pandas as pd
import matplotlib.pyplot as plt

# %%
class RobotEnv(gym.Env):    
    def __init__(self,idx=0):
        super(RobotEnv, self).__init__()

        self.velocity=1.0
        self.orientation=0.0
        self.steps=1
        #self.max_step=1000
        
        # Load CSV data
        self.files_df = pd.read_csv('filtered.csv')
        self.annotations_df = pd.read_csv('filtered_annotations.csv') 
        self.depth_paths_df = pd.read_csv('filtered_objDepth.csv')
        
        # Define action space
        self.action_space = spaces.Discrete(4)  # [left, right, forward, stop]
        
        # Define observation space (depth image dimensions)
        self.observation_space = spaces.Box(
            low=0, high=255, 
            shape=(224, 640, 3),  # Example depth image dimensions
            dtype=np.uint8
        )

        self.current_index = idx
        self.state=Image.open(self.files_df.iloc[self.current_index]['filename'])

    def _process_depth_image(self, depth_path):
        depth_img = cv2.imread(depth_path, cv2.IMREAD_GRAYSCALE)
        
        # Split image into 3 vertical sections
        height, width = depth_img.shape
        section_width = width // 3
        
        left_section = depth_img[:, :section_width]
        center_section = depth_img[:, section_width:2*section_width]
        right_section = depth_img[:, 2*section_width:]
        
        return left_section, center_section, right_section

    def _get_obstacle_status(self, section):
        # Convert pixel values to meters (assuming 0-255 maps to 0-30m)
        depth_in_meters = (section / 255) * 30  
        return np.any(depth_in_meters < 15)

    def step(self, action):
        # Get current data
        depth_path = self.depth_paths_df.iloc[self.current_index]['depth_file_path']
        left, center, right = self._process_depth_image(depth_path)
        
        # Detect obstacles in each section
        obstacles = {
            'left': self._get_obstacle_status(left),
            'center': self._get_obstacle_status(center),
            'right': self._get_obstacle_status(right)
        }

        if action==0:
            self.orientation-=30
            self.velocity-=0.2
        elif action==1:
            self.orientation+=30
            self.velocity-=0.2
        elif action==2:
            self.orientation=0.0
            self.velocity+=0.2
        else:            
            self.orientation=0.0
            self.velocity=0.0
        
        # Calculate reward and done status
        reward = 0
        done = False
        
        # Simple collision avoidance logic
        if action == 0 and obstacles['left']:
            reward -= 50
        elif action == 1 and obstacles['right']:
            reward -= 50
        elif action == 2 and obstacles['center']: 
            reward -= 50
        else:
            reward += 1
            
        self.current_index += 1
        self.steps+=1
        if self.current_index >= 150: #len(self.files_df)
            done = True
        else:
            # Load next image as NumPy array
            self.state = Image.open(self.files_df.iloc[self.current_index]['filename'])
            self.state = np.array(self.state, dtype=np.uint8)
            if self.state.shape != (224, 640, 3):
                self.state = np.array(Image.fromarray(self.state).resize((640, 224)))
        
        return self.state, reward, done, {'Step':self.steps}

    def reset(self):
        self.velocity=1.0
        self.orientation=0.0
        self.steps=1
        self.current_index = 0
        self.state=Image.open(self.files_df.iloc[self.current_index]['filename'])
        self.state = np.array(self.state, dtype=np.uint8)  # Convert to NumPy array
        if self.state.shape != (224, 640, 3):
            self.state = np.array(Image.fromarray(self.state).resize((640, 224)))
        return self.state

# %%
# Define the DQN model
class DQN(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_size, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, output_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# Define the ReplayMemory
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward', 'done'))

class ReplayMemory:
    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# DQN Agent
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.state_size = state_size
        self.action_size = action_size
        self.memory = ReplayMemory(10000)
        self.gamma = 0.99
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.01
        self.batch_size = 64

        self.policy_net = DQN(state_size, action_size).to(self.device)
        self.target_net = DQN(state_size, action_size).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.learning_rate)

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        with torch.no_grad():
            state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
            q_values = self.policy_net(state)
            return q_values.argmax().item()

    def remember(self, state, action, reward, next_state, done):
        self.memory.push(state, action, next_state, reward, done)

    def replay(self):
        if len(self.memory) < self.batch_size:
            return

        transitions = self.memory.sample(self.batch_size)
        batch = Transition(*zip(*transitions))

        state_batch = torch.FloatTensor(batch.state).to(self.device)
        action_batch = torch.LongTensor(batch.action).unsqueeze(1).to(self.device)
        reward_batch = torch.FloatTensor(batch.reward).to(self.device)
        next_state_batch = torch.FloatTensor(batch.next_state).to(self.device)
        done_batch = torch.FloatTensor(batch.done).to(self.device)

        q_values = self.policy_net(state_batch).gather(1, action_batch)
        next_q_values = self.target_net(next_state_batch).max(1)[0].detach()
        expected_q_values = reward_batch + self.gamma * next_q_values * (1 - done_batch)

        loss = nn.MSELoss()(q_values, expected_q_values.unsqueeze(1))
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

# Main function
def main():
    # Create environment
    env = RobotEnv()

    # Create agent
    state_size = 224 * 640 * 3  # Flattened image size
    action_size = 4
    agent = DQNAgent(state_size, action_size)

    # Training loop
    num_episodes = 1
    for episode in range(num_episodes):
        state = env.reset()  # Returns NumPy array (224, 640, 3)
        state = state.flatten()  # Flatten to (430080,)
        total_reward = 0
        done = False

        while not done:
            action = agent.act(state)
            next_state, reward, done, info = env.step(action)
            next_state = next_state.flatten()  # Flatten next_state

            agent.remember(state, action, reward, next_state, done)
            agent.replay()

            state = next_state
            total_reward += reward
            print(info)

        if episode % 10 == 0:
            agent.update_target_network()

        print(f"Episode {episode + 1}, Total Reward: {total_reward}, Epsilon: {agent.epsilon:.2f}")

    return agent, env  # Return for testing

# %%
agent,env = main()
# Out:
# {'Step': 2}
# {'Step': 3}
# {'Step': 4}
# {'Step': 5}
# {'Step': 6}
# {'Step': 7}
# {'Step': 8}
# {'Step': 9}
# {'Step': 10}
# {'Step': 11}
# {'Step': 12}
# {'Step': 13}
# {'Step': 14}
# {'Step': 15}
# {'Step': 16}
# {'Step': 17}
# {'Step': 18}
# {'Step': 19}
# {'Step': 20}
# {'Step': 21}
# {'Step': 22}
# {'Step': 23}
# {'Step': 24}
# {'Step': 25}
# {'Step': 26}
# {'Step': 27}
# {'Step': 28}
# {'Step': 29}
# {'Step': 30}
# {'Step': 31}
# {'Step': 32}
# {'Step': 33}
# {'Step': 34}
# {'Step': 35}
# {'Step': 36}
# {'Step': 37}
# {'Step': 38}
# {'Step': 39}
# {'Step': 40}
# {'Step': 41}
# {'Step': 42}
# {'Step': 43}
# {'Step': 44}
# {'Step': 45}
# {'Step': 46}
# {'Step': 47}
# {'Step': 48}
# {'Step': 49}
# {'Step': 50}
# {'Step': 51}
# {'Step': 52}
# {'Step': 53}
# {'Step': 54}
# {'Step': 55}
# {'Step': 56}
# {'Step': 57}
# {'Step': 58}
# {'Step': 59}
# {'Step': 60}
# {'Step': 61}
# {'Step': 62}
# {'Step': 63}
# {'Step': 64}
# {'Step': 65}
# {'Step': 66}
# {'Step': 67}
# {'Step': 68}
# ...

# %% [raw]
# data/export/1478898705647808375_jpg.rf.531f797f9dd845bfb886831bd792e2fd.jpg
# data/export/depth/depth_1478898705647808375_jpg.rf.531f797f9dd845bfb886831bd792e2fd.png

# %%
def test_with_image(agent, env):
    # Load and preprocess test image
    test_image = Image.open("data/export/1478898705647808375_jpg.rf.531f797f9dd845bfb886831bd792e2fd.jpg")
    test_image = test_image.resize((640, 224))
    test_image_np = np.array(test_image, dtype=np.uint8)
    
    if test_image_np.shape != (224, 640, 3):
        raise ValueError(f"Image shape {test_image_np.shape} does not match (224, 640, 3)")
    
    # Flatten for DQN input
    state = test_image_np.flatten()

    # Get best action
    original_epsilon = agent.epsilon
    agent.epsilon = 0.0  # Greedy policy
    action = agent.act(state)
    agent.epsilon = original_epsilon

    action_names = {0: "Left", 1: "Right", 2: "Forward", 3: "Stop"}

    # Step environment
    env.state = test_image_np  # Set as NumPy array
    env.current_index = 10044

    next_state, reward, done, info = env.step(action)

    # Print and show results
    print(f"Action Taken: {action_names[action]} (Action ID: {action})")
    print(f"Reward: {reward}")
    plt.figure(figsize=(10, 5))
    plt.imshow(test_image_np)
    plt.title(f"Test Image - Action: {action_names[action]}, Reward: {reward}")
    plt.axis('off')
    plt.show()

# %%
test_with_image(agent,env)
# Out:
# Action Taken: Right (Action ID: 1)
# Reward: -50

# %%
env=RobotEnv()
env.reset()
i=0
total_reward=0
for i in range(1000):
    action = env.action_space.sample()
    ns, reward, done, _ = env.step(action)
    total_reward += reward
    print(f"i: {i}, Next state: {ns}, Action: {action}, Reward: {reward:.2f}")
    i+=1
print(f"\nEpisode finished with total reward: {total_reward:.2f}")

# %%
df=pd.read_csv('filtered.csv')
first_row = df.iloc[0]['filename']
print("\nFirst row:")
print(first_row)
# Out:
# First row:
# 1478019952686311006_jpg.rf.54e2d12dbabc46be3c78995b6eaf3fee.jpg

# %%
import cv2
import numpy as np

def estimate_obstacle_depths(depth_image_path, bounding_boxes):
    # Load the depth image (16-bit PNG or other format)
    depth_image = cv2.imread(depth_image_path, cv2.IMREAD_UNCHANGED)
    if depth_image is None:
        raise ValueError("Failed to load depth image. Check the file path.")

    # Convert to single channel if multi-channel (e.g., RGB depth map)
    if len(depth_image.shape) == 3:
        depth_image = cv2.cvtColor(depth_image, cv2.COLOR_BGR2GRAY)
    elif len(depth_image.shape) != 2:
        raise ValueError(f"Unexpected depth image shape: {depth_image.shape}")

    # Get image dimensions
    height, width = depth_image.shape
    section_width = width // 3  # Divide width into three vertical sections

    # Define the 3 vertical sections (Left, Center, Right)
    section_ranges = {
        'Left': (0, section_width),
        'Center': (section_width, 2 * section_width),
        'Right': (2 * section_width, width)
    }

    # Initialize results
    section_obstacles = {'Left': [], 'Center': [], 'Right': []}

    # Assign each bounding box to a section and compute its depth
    for bbox in bounding_boxes:
        xmin, ymin, xmax, ymax = bbox

        # Ensure bounding box is within image bounds
        xmin = max(0, min(xmin, width - 1))
        xmax = max(xmin + 1, min(xmax, width))
        ymin = max(0, min(ymin, height - 1))
        ymax = max(ymin + 1, min(ymax, height))

        # Determine which section the bbox falls into based on its x-center
        center_x = (xmin + xmax) // 2
        for section, (x_min, x_max) in section_ranges.items():
            if x_min <= center_x < x_max:
                # Extract ROI for this obstacle
                roi_depth = depth_image[ymin:ymax, xmin:xmax]
                if roi_depth.size > 0:
                    valid_depths = roi_depth[roi_depth > 0]
                    if valid_depths.size > 0:
                        estimated_depth = np.median(valid_depths)  # Depth for this obstacle
                        section_obstacles[section].append((estimated_depth, bbox))
                    else:
                        section_obstacles[section].append((float('inf'), bbox))
                else:
                    section_obstacles[section].append((float('inf'), bbox))
                break

    return section_obstacles

# Example usage
depth_image_path = "data/export/depth/depth_1478900957671553561_jpg.rf.d72d23d428740d677811e01d678f8278.png"
bounding_boxes = [
    (40, 62, 69, 147), (503, 512, 250, 311), (19, 57, 256, 290), 
    (65, 104, 259, 292), (108, 138, 259, 285), (110, 136, 258, 282), 
    (136, 148, 203, 231), (138, 146, 204, 227), (140, 176, 254, 290), 
    (145, 174, 259, 288), (147, 155, 201, 227), (187, 281, 233, 361), 
    (227, 240, 160, 197), (229, 238, 164, 188), (274, 282, 222, 241), 
    (306, 399, 151, 317)
]

try:
    results = estimate_obstacle_depths(depth_image_path, bounding_boxes)

    # Print results
    for section, obstacles in results.items():
        print(f"\nSection: {section}")
        if obstacles:
            for i, (depth, bbox) in enumerate(obstacles):
                print(f"  Obstacle {i}: Depth = {depth:.2f}, BBox = {bbox}")
        else:
            print("  No obstacles detected")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Section: Left
#   Obstacle 0: Depth = 103.00, BBox = (40, 62, 69, 147)
#   Obstacle 1: Depth = 75.00, BBox = (19, 57, 256, 290)
#   Obstacle 2: Depth = 76.00, BBox = (65, 104, 259, 292)
#   Obstacle 3: Depth = 45.00, BBox = (136, 148, 203, 231)
#
# Section: Center
#   Obstacle 0: Depth = 76.00, BBox = (108, 138, 259, 285)
#   Obstacle 1: Depth = 76.00, BBox = (110, 136, 258, 282)
#   Obstacle 2: Depth = 45.00, BBox = (138, 146, 204, 227)
#   Obstacle 3: Depth = 81.00, BBox = (140, 176, 254, 290)
#   Obstacle 4: Depth = 81.00, BBox = (145, 174, 259, 288)
#   Obstacle 5: Depth = 45.00, BBox = (147, 155, 201, 227)
#   Obstacle 6: Depth = 111.00, BBox = (187, 281, 233, 361)
#   Obstacle 7: Depth = 105.00, BBox = (227, 240, 160, 197)
#   Obstacle 8: Depth = 100.00, BBox = (229, 238, 164, 188)
#   Obstacle 9: Depth = 88.00, BBox = (274, 282, 222, 241)
#   Obstacle 10: Depth = 200.00, BBox = (306, 399, 151, 317)
#
# Section: Right
#   Obstacle 0: Depth = 200.00, BBox = (503, 512, 250, 311)

# %%
import pandas as pd

def get_annotations_for_filename(annotations_df, filename):
    # Filter rows by filename
    matching_rows = annotations_df[annotations_df['filename'] == filename]
    
    # Create list of tuples
    annotations_list = [
        (row['xmin'], row['xmax'], row['ymin'], row['ymax'])
        for _, row in matching_rows.iterrows()
    ]
    
    return annotations_list

# Example usage within your RobotEnv or standalone
def example_usage():
    # Assuming annotations_df is loaded as in RobotEnv
    annotations_df = pd.read_csv('filtered_annotations.csv')
    
    # Example filename
    filename = "data/export/1478900957671553561_jpg.rf.d72d23d428740d677811e01d678f8278.jpg"  # Replace with your actual filename
    
    # Get annotations
    annotations = get_annotations_for_filename(annotations_df, filename)
    
    # Print results
    print(f"Annotations for {filename}:")
    print(annotations)

# Run example
if __name__ == "__main__":
    example_usage()
# Out:
# Annotations for data/export/1478900957671553561_jpg.rf.d72d23d428740d677811e01d678f8278.jpg:
# [(40, 62, 69, 147), (503, 512, 250, 311), (19, 57, 256, 290), (65, 104, 259, 292), (108, 138, 259, 285), (110, 136, 258, 282), (136, 148, 203, 231), (138, 146, 204, 227), (140, 176, 254, 290), (145, 174, 259, 288), (147, 155, 201, 227), (187, 281, 233, 361), (227, 240, 160, 197), (229, 238, 164, 188), (274, 282, 222, 241), (306, 399, 151, 317)]

# %%
import cv2
import numpy as np

def estimate_obstacle_depths(depth_image_path, bounding_boxes, depth_scale=30.0/255.0, unit="meters"):
    # Load the depth image
    depth_image = cv2.imread(depth_image_path, cv2.IMREAD_UNCHANGED)
    if depth_image is None:
        raise ValueError("Failed to load depth image. Check the file path.")

    # Print original image details
    print("Original - Shape:", depth_image.shape, "Dtype:", depth_image.dtype, 
          "Min:", depth_image.min(), "Max:", depth_image.max())

    # Convert to single channel if multi-channel
    if len(depth_image.shape) == 3:
        depth_image = cv2.cvtColor(depth_image, cv2.COLOR_BGR2GRAY)
    elif len(depth_image.shape) != 2:
        raise ValueError(f"Unexpected depth image shape: {depth_image.shape}")

    # Print after conversion
    print("After conversion - Shape:", depth_image.shape, "Dtype:", depth_image.dtype, 
          "Min:", depth_image.min(), "Max:", depth_image.max())

    # Get image dimensions
    height, width = depth_image.shape
    section_width = width // 3

    # Define the 3 vertical sections
    section_ranges = {
        'Left': (0, section_width),
        'Center': (section_width, 2 * section_width),
        'Right': (2 * section_width, width)
    }

    # Initialize results
    section_obstacles = {'Left': [], 'Center': [], 'Right': []}

    # Assign each bounding box to a section and compute its depth
    for bbox in bounding_boxes:
        xmin, ymin, xmax, ymax = bbox

        # Ensure bounding box is within image bounds
        xmin = max(0, min(xmin, width - 1))
        xmax = max(xmin + 1, min(xmax, width))
        ymin = max(0, min(ymin, height - 1))
        ymax = max(ymin + 1, min(ymax, height))

        # Determine which section the bbox falls into based on x-center
        center_x = (xmin + xmax) // 2
        for section, (x_min, x_max) in section_ranges.items():
            if x_min <= center_x < x_max:
                # Extract ROI for this obstacle
                roi_depth = depth_image[ymin:ymax, xmin:xmax]
                if roi_depth.size > 0:
                    valid_depths = roi_depth[roi_depth > 0]
                    if valid_depths.size > 0:
                        estimated_depth = np.median(valid_depths) * depth_scale
                        section_obstacles[section].append((estimated_depth, bbox))
                    else:
                        section_obstacles[section].append((float('inf'), bbox))
                else:
                    section_obstacles[section].append((float('inf'), bbox))
                break

    return section_obstacles

# Example usage
depth_image_path = "data/export/depth/depth_1478900957671553561_jpg.rf.d72d23d428740d677811e01d678f8278.png"
bounding_boxes = [(40, 62, 69, 147), (503, 512, 250, 311), (19, 57, 256, 290), (65, 104, 259, 292), (108, 138, 259, 285), (110, 136, 258, 282), (136, 148, 203, 231), (138, 146, 204, 227), (140, 176, 254, 290), (145, 174, 259, 288), (147, 155, 201, 227), (187, 281, 233, 361), (227, 240, 160, 197), (229, 238, 164, 188), (274, 282, 222, 241), (306, 399, 151, 317)]
try:
    results = estimate_obstacle_depths(depth_image_path, bounding_boxes, depth_scale=30.0/255.0, unit="meters")
    
    # Print results
    for section, obstacles in results.items():
        print(f"\nSection: {section}")
        if obstacles:
            for i, (depth, bbox) in enumerate(obstacles):
                print(f"  Obstacle {i}: Depth = {depth:.2f} meters, BBox = {bbox}")
        else:
            print("  No obstacles detected")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Original - Shape: (512, 512, 3) Dtype: uint8 Min: 1 Max: 230
# After conversion - Shape: (512, 512) Dtype: uint8 Min: 30 Max: 200
#
# Section: Left
#   Obstacle 0: Depth = 12.12 meters, BBox = (40, 62, 69, 147)
#   Obstacle 1: Depth = 8.82 meters, BBox = (19, 57, 256, 290)
#   Obstacle 2: Depth = 8.94 meters, BBox = (65, 104, 259, 292)
#   Obstacle 3: Depth = 5.29 meters, BBox = (136, 148, 203, 231)
#
# Section: Center
#   Obstacle 0: Depth = 8.94 meters, BBox = (108, 138, 259, 285)
#   Obstacle 1: Depth = 8.94 meters, BBox = (110, 136, 258, 282)
#   Obstacle 2: Depth = 5.29 meters, BBox = (138, 146, 204, 227)
#   Obstacle 3: Depth = 9.53 meters, BBox = (140, 176, 254, 290)
#   Obstacle 4: Depth = 9.53 meters, BBox = (145, 174, 259, 288)
#   Obstacle 5: Depth = 5.29 meters, BBox = (147, 155, 201, 227)
#   Obstacle 6: Depth = 13.06 meters, BBox = (187, 281, 233, 361)
#   Obstacle 7: Depth = 12.35 meters, BBox = (227, 240, 160, 197)
# ...
