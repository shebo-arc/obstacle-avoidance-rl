# %%
# !pip install import-ipynb

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from PIL import Image
#from transformers import DPTFeatureExtractor, DPTForDepthEstimation
#from ultralytics import YOLO
import gym
from gym import spaces
from collections import namedtuple, deque
import random

# %%
import import_ipynb
import objDet
import dpt_map

# %%
# Define a custom dataset class to load images and depth maps
class DepthDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.csv_file = pd.read_csv(csv_file)
        self.transform = transform

    def __len__(self):
        return len(self.csv_file)

    def __getitem__(self, idx):
        image_path = self.csv_file.iloc[idx, 0]
        depth_path = self.csv_file.iloc[idx, 1]

        image = Image.open(image_path)
        depth_map = np.load(depth_path)

        if self.transform:
            image = self.transform(image)

        # Convert depth map to tensor
        depth_map = torch.from_numpy(depth_map).unsqueeze(0)

        return image, depth_map

# %%
# Define the DQN model
class DQN(nn.Module):
    def __init__(self, input_size, output_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(input_size, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, output_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# Define the ReplayMemory
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward', 'done'))

class ReplayMemory:
    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# Environment class
class AutonomousVehicleEnv(gym.Env):
    def __init__(self):
        super().__init__()
        self.action_space = spaces.Discrete(4)  # stop, right, left, straight
        self.observation_space = spaces.Box(low=0, high=255, shape=(224, 640, 3), dtype=np.uint8)

    def step(self, action):
        # Implement environment dynamics
        # For simplicity, we'll just return a random observation and reward
        observation = self.observation_space.sample()
        reward = np.random.uniform(-1, 1)
        done = False
        info = {}
        return observation, reward, done, info

    def reset(self):
        return self.observation_space.sample()

# DQN Agent
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.state_size = state_size
        self.action_size = action_size
        self.memory = ReplayMemory(10000)
        self.gamma = 0.99
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.batch_size = 64

        self.policy_net = DQN(state_size, action_size).to(self.device)
        self.target_net = DQN(state_size, action_size).to(self.device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.target_net.eval()

        self.optimizer = optim.Adam(self.policy_net.parameters(), lr=self.learning_rate)

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        with torch.no_grad():
            state = torch.FloatTensor(state).unsqueeze(0).to(self.device)
            q_values = self.policy_net(state)
            return q_values.argmax().item()

    def remember(self, state, action, reward, next_state, done):
        self.memory.push(state, action, next_state, reward, done)

    def replay(self):
        if len(self.memory) < self.batch_size:
            return

        transitions = self.memory.sample(self.batch_size)
        batch = Transition(*zip(*transitions))

        state_batch = torch.FloatTensor(batch.state).to(self.device)
        action_batch = torch.LongTensor(batch.action).unsqueeze(1).to(self.device)
        reward_batch = torch.FloatTensor(batch.reward).to(self.device)
        next_state_batch = torch.FloatTensor(batch.next_state).to(self.device)
        done_batch = torch.FloatTensor(batch.done).to(self.device)

        q_values = self.policy_net(state_batch).gather(1, action_batch)
        next_q_values = self.target_net(next_state_batch).max(1)[0].detach()
        expected_q_values = reward_batch + self.gamma * next_q_values * (1 - done_batch)

        loss = nn.MSELoss()(q_values, expected_q_values.unsqueeze(1))
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def update_target_network(self):
        self.target_net.load_state_dict(self.policy_net.state_dict())

# Main function
def main():
    # Load models
    object_detection_model = "runs/detect/train/weights/best.pt"
    yolo = objDet.YOLOTrainerDetector()

    # Create environment
    env = AutonomousVehicleEnv()

    # Create agent
    state_size = 224 * 640 * 3  # Flattened image size
    action_size = 4
    agent = DQNAgent(state_size, action_size)

    # Training loop
    num_episodes = 3
    for episode in range(num_episodes):
        state = env.reset()
        state = state.flatten()  # Flatten the state
        total_reward = 0
        done = False

        while not done:
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            next_state = next_state.flatten()  # Flatten the next state

            # Convert observation to image
            image = Image.fromarray(next_state.reshape(224, 640, 3).astype('uint8'))

            # Predict depth
            depth_map = dpt_map.findDepth(image)

            # Detect objects
            detected_objects = detect_objects(image, object_detection_model)

            # Use depth_map and detected_objects to modify the reward
            # This is a simple example and should be replaced with more sophisticated logic
            if np.min(depth_map) < 10:  # If very close to an obstacle
                reward -= 1
            if len(detected_objects) > 0:  # If objects detected
                reward += 5

            agent.remember(state, action, reward, next_state, done)
            agent.replay()

            state = next_state
            total_reward += reward

        if episode % 10 == 0:
            agent.update_target_network()

        print(f"Episode {episode + 1}, Total Reward: {total_reward}, Epsilon: {agent.epsilon:.2f}")

# Test the agent with a random image
def test_agent(agent, env, image, depth_map):
    # Combine the image and depth map
    state = np.concatenate((image, depth_map), axis=0)

    # Display the input state
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    plt.title("RGB Image")
    plt.subplot(1, 2, 2)
    plt.imshow(depth_map, cmap='gray')
    plt.title("Depth Map")
    plt.show()

    # Get the action from the agent
    action = agent.act(state)

    print(f"Input State Shape: {state.shape}")
    print(f"Output Action: {action}")

# %%
# Call the test function after training
main()
# Create environment and agent
env = AutonomousVehicleEnv()
agent = DQNAgent((4, 224, 640), 4)

# Load the CSV file containing image and depth map paths
csv_file_path = 'your/actual/path/to/dataset.csv'  # Update this path

try:
    dataset = pd.read_csv(csv_file_path)
except FileNotFoundError:
    print("The file does not exist. Please check the path.")
else:
    # Select a random row from the dataset
    random_row = dataset.sample(n=1)

    # Load the image and depth map
    image_path = random_row['filename'].values[0]
    depth_path = random_row['depth_file_path'].values[0]

    # Load the image and depth map
    try:
        image = np.array(Image.open(image_path))
        depth_map = np.load(depth_path)
    except Exception as e:
        print(f"Failed to load image or depth map: {e}")
    else:
        # Display the image and depth map
        plt.figure(figsize=(10, 5))
        plt.subplot(1, 2, 1)
        plt.imshow(image)
        plt.title("RGB Image")
        plt.subplot(1, 2, 2)
        plt.imshow(depth_map, cmap='gray')
        plt.title("Depth Map")
        plt.show()

        # Optionally, print the shape of the image and depth map
        print("Image Shape:", image.shape)
        print("Depth Map Shape:", depth_map.shape)
    # Test the agent
    test_agent(agent, env, image, depth_map)

# %%
import numpy as np
import gym
from gym import spaces
import cv2
from collections import deque
import time

class RobotEnv(gym.Env):
    """
    Reinforcement Learning environment for a robot moving in a space with image observations
    Actions: left, right, forward, backward, stop
    State: Image inputs (continuous state space)
    """
    
    # Action space constants
    LEFT = 0
    RIGHT = 1
    FORWARD = 2
    BACKWARD = 3
    STOP = 4
    
    def __init__(self, image_width=640, image_height=480, frame_stack=4, max_steps=500):
        super(RobotEnv, self).__init__()
        
        # Environment parameters
        self.image_width = image_width
        self.image_height = image_height
        self.frame_stack = frame_stack
        self.max_steps = max_steps
        self.current_step = 0
        self.delay = 0.5  # Delay between actions in seconds
        
        # Define action and observation spaces
        # 5 discrete actions: left, right, forward, backward, stop
        self.action_space = spaces.Discrete(5)
        
        # Image observation space (continuous)
        # Shape: (frame_stack, height, width, channels)
        self.observation_space = spaces.Box(
            low=0, high=255, 
            shape=(frame_stack, image_height, image_width, 3),
            dtype=np.uint8
        )
        
        # For frame stacking
        self.frames = deque(maxlen=frame_stack)
        
        # Robot state
        self.position = np.array([0.0, 0.0])  # (x, y)
        self.orientation = 0.0  # in radians
        self.velocity = 0.0
        
        # Environment state
        self.goal_position = np.array([10.0, 10.0])
        self.obstacles = [
            {"position": np.array([5.0, 5.0]), "radius": 1.0},
            {"position": np.array([7.0, 3.0]), "radius": 1.5}
        ]
        
        # Window name
        self.window_name = 'Robot Environment (Press Q to quit)'
        
        # Initialize frames
        self.reset()
    
    def reset(self):
        """Reset the environment to initial state and return the initial observation"""
        self.current_step = 0
        self.position = np.array([0.0, 0.0])
        self.orientation = 0.0
        self.velocity = 0.0
        
        # Clear frame stack and fill with initial frames
        self.frames.clear()
        initial_frame = self._render_frame()
        for _ in range(self.frame_stack):
            self.frames.append(initial_frame)
        
        return self._get_observation()
    
    def step(self, action):
        """
        Take an action in the environment
        Returns: observation, reward, done, info
        """
        self.current_step += 1
        
        # Execute action and update robot state
        self._execute_action(action)
        
        # Generate new frame and add to stack
        new_frame = self._render_frame()
        self.frames.append(new_frame)
        
        # Calculate reward
        reward = self._calculate_reward(action)
        
        # Check if episode is done
        done = self._is_done()
        
        # Additional info
        info = {
            "distance_to_goal": np.linalg.norm(self.position - self.goal_position),
            "velocity": self.velocity,
            "position": self.position.copy(),
            "step": self.current_step,
            "action_name": ["LEFT", "RIGHT", "FORWARD", "BACKWARD", "STOP"][action]
        }
        
        return self._get_observation(), reward, done, info
    
    def _execute_action(self, action):
        """Execute the given action and update robot's state"""
        # Define movement parameters
        move_speed = 0.2  # Reduced for slower movement
        turn_angle = np.pi / 20  # 9 degrees (reduced for slower turning)
        
        # Update orientation and position based on action
        if action == self.LEFT:
            self.orientation += turn_angle
            self.velocity = move_speed * 0.5  # Turning reduces speed
        elif action == self.RIGHT:
            self.orientation -= turn_angle
            self.velocity = move_speed * 0.5  # Turning reduces speed
        elif action == self.FORWARD:
            self.velocity = move_speed
        elif action == self.BACKWARD:
            self.velocity = -move_speed * 0.7  # Backward is slower
        elif action == self.STOP:
            self.velocity = 0.0
        
        # Update position based on velocity and orientation
        if self.velocity != 0:
            movement = np.array([
                np.cos(self.orientation) * self.velocity,
                np.sin(self.orientation) * self.velocity
            ])
            new_position = self.position + movement
            
            # Check for collisions with obstacles
            collision = False
            for obstacle in self.obstacles:
                dist = np.linalg.norm(new_position - obstacle["position"])
                if dist < obstacle["radius"]:
                    collision = True
                    break
            
            if not collision:
                self.position = new_position
            else:
                self.velocity = 0.0  # Stop on collision
    
    def _calculate_reward(self, action):
        """Calculate reward based on action and state"""
        reward = 0.0
        
        # Distance to goal
        prev_distance = np.linalg.norm(self.position - self.goal_position - self._get_action_movement(action))
        current_distance = np.linalg.norm(self.position - self.goal_position)
        
        # Reward for getting closer to goal
        if current_distance < prev_distance:
            reward += 1.0
        else:
            reward -= 0.5
        
        # Penalty for unnecessary stop
        if action == self.STOP and current_distance > 1.0:
            reward -= 0.5
        
        # Reward for reaching goal
        if current_distance < 1.0:
            reward += 10.0
            if action == self.STOP:  # Extra reward for stopping at goal
                reward += 5.0
        
        # Penalty for collisions
        for obstacle in self.obstacles:
            dist = np.linalg.norm(self.position - obstacle["position"])
            if dist < obstacle["radius"] + 0.1:  # Small buffer
                reward -= 5.0
                break
        
        # Small penalty for each step to encourage efficiency
        reward -= 0.01
        
        # Reward for moving at appropriate speed
        if 0 < current_distance < 5.0 and self.velocity > 0:
            reward += 0.1
        
        return reward
    
    def _get_action_movement(self, action):
        """Get movement vector for an action (for reward calculation)"""
        if action == self.FORWARD:
            return np.array([np.cos(self.orientation) * 0.2, np.sin(self.orientation) * 0.2])
        elif action == self.BACKWARD:
            return np.array([-np.cos(self.orientation) * 0.14, -np.sin(self.orientation) * 0.14])
        return np.array([0.0, 0.0])
    
    def _is_done(self):
        """Check if episode is done"""
        # Done if reached goal and stopped
        goal_reached = np.linalg.norm(self.position - self.goal_position) < 1.0
        
        # Done if max steps reached
        steps_done = self.current_step >= self.max_steps
        
        return goal_reached or steps_done
    
    def _render_frame(self):
        """Render the current state as an RGB image"""
        # Create a blank image (simple 2D grid for demonstration)
        frame = np.zeros((self.image_height, self.image_width, 3), dtype=np.uint8)
        
        # Fill with dark gray background
        frame.fill(30)
        
        # Add grid lines
        grid_spacing = 40
        grid_color = (50, 50, 50)
        for x in range(0, self.image_width, grid_spacing):
            cv2.line(frame, (x, 0), (x, self.image_height), grid_color, 1)
        for y in range(0, self.image_height, grid_spacing):
            cv2.line(frame, (0, y), (self.image_width, y), grid_color, 1)
        
        # Scale coordinates to image dimensions
        scale_x = self.image_width / 20.0
        scale_y = self.image_height / 20.0
        
        # Draw goal (green)
        goal_x = int(self.goal_position[0] * scale_x)
        goal_y = int(self.goal_position[1] * scale_y)
        cv2.circle(frame, (goal_x, goal_y), 20, (0, 255, 0), -1)
        cv2.circle(frame, (goal_x, goal_y), 25, (0, 200, 0), 2)
        cv2.putText(frame, "GOAL", (goal_x - 30, goal_y - 30), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        
        # Draw obstacles (red)
        for i, obstacle in enumerate(self.obstacles):
            obs_x = int(obstacle["position"][0] * scale_x)
            obs_y = int(obstacle["position"][1] * scale_y)
            radius = int(obstacle["radius"] * scale_x)
            cv2.circle(frame, (obs_x, obs_y), radius, (0, 0, 255), -1)
            cv2.circle(frame, (obs_x, obs_y), radius + 2, (0, 0, 200), 2)
            cv2.putText(frame, f"OBS {i+1}", (obs_x - 25, obs_y - radius - 10), 
                      cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)
        
        # Draw robot (blue with yellow direction indicator)
        robot_x = int(self.position[0] * scale_x)
        robot_y = int(self.position[1] * scale_y)
        
        # Robot body
        cv2.circle(frame, (robot_x, robot_y), 15, (255, 0, 0), -1)
        cv2.circle(frame, (robot_x, robot_y), 17, (200, 0, 0), 2)
        
        # Robot direction indicator
        end_x = int(robot_x + 25 * np.cos(self.orientation))
        end_y = int(robot_y + 25 * np.sin(self.orientation))
        cv2.line(frame, (robot_x, robot_y), (end_x, end_y), (255, 255, 0), 3)
        
        # Draw robot info
        cv2.putText(frame, "ROBOT", (robot_x - 30, robot_y - 25), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 2)
        
        # Add environment information as text
        info_y = 30
        cv2.putText(frame, f"Step: {self.current_step}/{self.max_steps}", 
                    (10, info_y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)
        info_y += 25
        cv2.putText(frame, f"Robot Position: ({self.position[0]:.1f}, {self.position[1]:.1f})", 
                    (10, info_y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)
        info_y += 25
        cv2.putText(frame, f"Distance to Goal: {np.linalg.norm(self.position - self.goal_position):.2f}", 
                    (10, info_y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)
        info_y += 25
        cv2.putText(frame, f"Velocity: {self.velocity:.2f}", 
                    (10, info_y), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)
        
        return frame
    
    def _get_observation(self):
        """Get the stacked frames as observation"""
        return np.array(self.frames)
    
    def render(self, mode='human'):
        """Render the environment"""
        frame = self._render_frame()
        
        if mode == 'human':
            cv2.imshow(self.window_name, frame)
            key = cv2.waitKey(1)
            
            # Add delay to slow down visualization
            time.sleep(self.delay)
            
            # Check if user wants to quit (press 'q')
            if key == ord('q'):
                self.close()
                return None
            
            return None
        elif mode == 'rgb_array':
            return frame
        
    def close(self):
        """Clean up resources"""
        cv2.destroyAllWindows()


# Example usage
if __name__ == "__main__":
    # Create environment
    env = RobotEnv()
    
    # Test environment with random actions
    obs = env.reset()
    done = False
    total_reward = 0
    
    # Print instructions
    print("\nRobot Environment Test")
    print("======================")
    print("Press 'q' in the window to quit")
    print("Random actions will be taken automatically")
    print("Actions: 0=LEFT, 1=RIGHT, 2=FORWARD, 3=BACKWARD, 4=STOP\n")
    
    try:
        while not done:
            # Random action
            action = env.action_space.sample()
            
            # Take step
            obs, reward, done, info = env.step(action)
            total_reward += reward
            
            # Render (this includes delay)
            env.render()
            
            # Print info
            print(f"Action: {info['action_name']}, Reward: {reward:.2f}, Position: ({info['position'][0]:.1f}, {info['position'][1]:.1f})")
            
        print(f"\nEpisode finished with total reward: {total_reward:.2f}")
    
    except KeyboardInterrupt:
        print("\nSimulation stopped by user")
    
    finally:
        env.close()
# Out:
# Robot Environment Test
# ...
# Press 'q' in the window to quit
# Random actions will be taken automatically
# Actions: 0=LEFT, 1=RIGHT, 2=FORWARD, 3=BACKWARD, 4=STOP
#
# Action: BACKWARD, Reward: -0.51, Position: (-0.1, 0.0)
# Action: BACKWARD, Reward: -0.51, Position: (-0.3, 0.0)
# Action: BACKWARD, Reward: -0.51, Position: (-0.4, 0.0)
# Action: LEFT, Reward: -0.51, Position: (-0.3, 0.0)
# Action: STOP, Reward: -1.01, Position: (-0.3, 0.0)
# Action: LEFT, Reward: -0.51, Position: (-0.2, 0.0)
# Action: RIGHT, Reward: -0.51, Position: (-0.1, 0.1)
# Action: BACKWARD, Reward: -0.51, Position: (-0.3, 0.0)
# Action: LEFT, Reward: -0.51, Position: (-0.2, 0.1)
# Action: STOP, Reward: -1.01, Position: (-0.2, 0.1)
# Action: BACKWARD, Reward: -0.51, Position: (-0.3, 0.0)
# Action: STOP, Reward: -1.01, Position: (-0.3, 0.0)
# Action: FORWARD, Reward: 0.99, Position: (-0.1, 0.1)
# Action: BACKWARD, Reward: -0.51, Position: (-0.2, 0.0)
# Action: STOP, Reward: -1.01, Position: (-0.2, 0.0)
# ...
